# %% [markdown]
# ## Namespace and Scope

# %% [markdown]
# ###`Q1:` Write `Person` Class as given below and then display it's namespace.

# %% [markdown]
# ```
# Class Name - Person
#
# Attributes:
# name - public
# state - public
# city - private
# age - private
#
# Methods:
# address - public
# It give address of the person as "<name>, <city>, <state>"
# ```

# %%
class Person:
  def __init__(self,name,state,city,age):
    self.name=name
    self.state=state
    self.__city= city
    self.__age=age


  def address(self):
    print(f"<{self.name}>,<{self.__city}>,<{self.state}>")

print(Person.__dict__)
# Out:
# {'__module__': '__main__', '__init__': <function Person.__init__ at 0x00000148D5E709A0>, 'address': <function Person.address at 0x00000148D5E70A40>, '__dict__': <attribute '__dict__' of 'Person' objects>, '__weakref__': <attribute '__weakref__' of 'Person' objects>, '__doc__': None}

# %% [markdown]
# ###`Q2:` Write a program to show namespace of object/instance of above(Person) class.

# %%
# Write your code here
p=Person("shandes","koshi",'gaighat','21')
print(p.__dict__)
# Out:
# {'name': 'shandes', 'state': 'koshi', '_Person__city': 'gaighat', '_Person__age': '21'}

# %% [markdown]
# ###`Q3:` Write a recursive program to to calculate `gcd` and print no. of function calls taken to find the solution.
# ```
# gcd(5,10) -> result in 5 as gcd and function call 4
# ```

# %%
def GCD(a,b,n=1):
    if b==0:
        return a,n+1
    else:
        return GCD(b,a%b,n+1)

a,n=GCD(5,10)
print(f"Result in {a} as gcd and function call {n}")
# Out:
# Result in 5 as gcd and function call 4

# %% [markdown]
# ## Itterator And Generator

# %% [markdown]
# ###`Q4:` Create MyEnumerate class,
# Create your own `MyEnumerate` class such that someone can use it instead of enumerate. It will need to return a `tuple` with each iteration, with the first element in the tuple being the `index` (starting with 0) and the second element being the `current element` from the underlying data structure. Trying to use `MyEnumerate` with a noniterable argument will result in an error.
#
# ```
# for index, letter in MyEnumerate('abc'):
#     print(f'{index} : {letter}')
# ```
#
# Output:
# ```
# 0 : a
# 1 : b
# 2 : c
# ```

# %%
class MyEnumerate1:
    def __init__(self,iterable):
        self.iterable=iterable
    
    def __iter__(self):
        return NewIteration(self.iterable)
    
class NewIteration:
    def __init__(self,iterable):
        self.iterable=iter(iterable)
        self.index=0

    def __iter__(self):
        return self       
    
    def __next__(self):
        value=next(self.iterable)
        current= (self.index, value)
        self.index+=1
        return current

# %%
class MyEnumerate:
    def __init__(self,iterable):
        self.iterable=iterable
    
    def __iter__(self):
        index=0
        for i in self.iterable:
            yield (index,i)
            index +=1

# %%
for index, letter in MyEnumerate('abc'):
    print(f'{index} : {letter}')
# Out:
# 0 : a
# 1 : b
# 2 : c

# %% [markdown]
# ###`Q5:` Iterate in circle
# Define a class, `Circle`, that takes two arguments when defined: a sequence and a number. The idea is that the object will then return elements the defined number of times. If the number is greater than the number of elements, then the sequence  repeats as necessary. You can define an another class used as a helper (like I call `CircleIterator`).
#
# ```
# c = Circle('abc', 5)
# d = Circle('abc', 7)
# print(list(c))
# print(list(d))
# ```
#
# Output
# ```
# [a, b, c, a, b]
# [a, b, c, a, b, c, a]
# ```

# %%
class Circle:
    def __init__(self,iterable,times):
        self.iterable=iterable
        self.times=times
    
    def __iter__(self):
        return CircleIterator(self)
    
class CircleIterator:
    def __init__(self,circle_attribute):
        self.iterable=circle_attribute.iterable
        self.times=circle_attribute.times
        self.i=0
        self.n=len(self.iterable)
    
    def __iter__(self):
        return self

    def __next__(self):
        if self.i>=self.times:
            raise StopIteration
        current=self.iterable[self.i%self.n]
        self.i +=1
        return current

# %%
# class Circle:
#     def __init__(self,iterable,times):
#         self.iterable=iterable
#         self.times=times
    
#     def __iter__(self):
#         i=0
#         while True:
#             if self.times==i:
#                 break
#             yield self.iterable[i%len(self.iterable)]
#             i+=1

# %%
c = Circle('abc', 5)
d = Circle('abc', 7)
print(list(c))
print(list(d))
# Out:
# ['a', 'b', 'c', 'a', 'b']
# ['a', 'b', 'c', 'a', 'b', 'c', 'a']

# %% [markdown]
# ###`Q6:` Generator time elapsed
# Write a generator function whose argument must be iterable. With each iteration, the generator will return a two-element tuple. The first element in the tuple will be an integer indicating how many seconds have passed since the previous iteration. The tuple’s second element will be the next item from the passed argument.
#
# Note that the timing should be relative to the previous iteration, not when the
# generator was first created or invoked. Thus the timing number in the first iteration
# will be 0
#
# ```
# for t in elapsed_since('abcd'):
#     print(t)
#     time.sleep(2)
# ```
#
# Output:
# ```
# (0.0, 'a')
# (2.005651817999933, 'b')
# (2.0023095009998997, 'c')
# (2.001949742000079, 'd')
# ```
# Note: Your output may differ because of diffrent system has different processing configuration.

# %%
import time 

def time_elaped(iterable):
    start=time.time()
    for i in iterable:
        end=time.time()
        yield (end-start,i)
        start=end

# %%
for t in time_elaped('abcd'):
    print(t)
    time.sleep(2)
# Out:
# (0.0, 'a')
# (2.0015170574188232, 'b')
# (2.001591920852661, 'c')
# (2.000795364379883, 'd')

# %% [markdown]
# ## Decorators

# %% [markdown]
# ###`Q7:` Write a Python program to make a chain of function decorators (bold, italic, underline etc.) on a given function which prints "hello world"
#
# ```
# def hello():
#     return "hello world"
# ```
#
# ```
# bold - wrap string with <b> tag. <b>Str</b>
# italic - wrap string with <i> tag. <i>Str</i>
# underline- wrap string with <u> tag. <u>Str</u>
# ```

# %%
def newDecorator(func):
    def wrapper():
        element=func()
        newelement=f"<b><i><u>{element}</u></i></b>"
        return newelement
    return wrapper

# %%
@newDecorator
def Hello():
    return "Hello world"

# %%
h=Hello()
print(h)
# Out:
# <b><i><u>Hello world</u></i></b>

# %% [markdown]
# ###`Q8:` Write a decorator called `printer` which causes any decorated function to print their return values. If the return value of a given function is `None`, printer should do nothing.

# %%
def printer(func):
    def wrappper():
        returnValue=func()
        if returnValue is not None:
            print(returnValue)
        return returnValue
    return wrappper

@printer
def hello1():
    return 'Hello'

# %%
def printer(func):
    def wrapper(*args, **kwargs):
        result = func(*args, **kwargs)
        if result is not None:
            print(result)
        return result
    return wrapper
@printer
def hello1():
    return 'Hello'

# %%
h=hello1()
# Out:
# Hello

# %% [markdown]
# ###`Q9:` Make a decorator which calls a given function twice. You can assume the functions don't return anything important, but they may take arguments.
# ```
# #Lets say given function
# def hello(string):
#     print(string)
#
# #on calling after specified decorator is inplaced
# hello('hello')
# ```
#
# Output:
# ```
# hello
# hello
# ```

# %%
def funcTwice(func):
    def wrappper(*args, **kwargs):
        func(*args, **kwargs)
        func(*args, **kwargs)
    return wrappper

@funcTwice
def hello(string):
    print(string)

# %%
hello('hello')
# Out:
# hello
# hello

# %% [markdown]
# ### `Q10:` Write a decorator which doubles the return value of any function. And test that decoratos is working correctly or not using `asert`.
#
# ```
# add(2,3) -> result in 10. Without decorator it should be 5.
# ```

# %%
def double(func):
     def wrapper(*args, **kwargs):     
          result=2*func(*args, **kwargs)
          return result
     return wrapper

# @double
def add(a,b):
    return a+b

# %%
a=add(2,3)
print(a)
# Out:
# 5
