# %% [markdown]
# ###`Problem 1:` Combine two lists index-wise(columns wise)
#
# Write a program to add two lists index-wise. Create a new list that contains the 0th index item from both the list, then the 1st index item, and so on till the last element. any leftover items will get added at the end of the new list.
#
# `Given List:`
# ```
# list1 = ["M", "na", "i", "Kh"]
# list2 = ["y", "me", "s", "an"]
# ```
#
# `Output:`
# ```
# [['M','y'], ['na', me'], ['i', 's'], ['Kh', 'an']]
# ```

# %%
list1 = ["M", "na", "i", "Kh"]
list2 = ["y", "me", "s", "an"]
l=[]
for i in range(len(list1)):
  for j in range(len(list2)):
    if i==j:
      l.append([list1[i] ,list2[j]])

# l=[list(i) for i in zip(list1,list2) ]

print(l)
# Out:
# [['M', 'y'], ['na', 'me'], ['i', 's'], ['Kh', 'an']]

# %% [markdown]
# ### `Problem 2:` Add new item to list after a specified item
# Write a program to add item 7000 after 6000 in the following Python List
# ```
# list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]
# ```
# `Output:`
# ```
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]
# ```

# %%
list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]

# list1[2][2].insert(2,7000)
list1[2][2].append(7000)
print(list1)
# Out:
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

# %% [markdown]
# ###`Problem 3:` Update no of items available
#
# Suppose you are given a list of candy and another list of same size representing no of items of respective candy.
#
# i.e -
# ```
# candy_list = ['Jelly Belly','Kit Kat','Double Bubble','Milky Way','Three Musketeers']
# no_of_items = [10,20,34,74,32]
# ```
#
# Write a program to show no. of items of each candy type.
#
# `Output:`
#
# ```
# Jelly Belly-10
# Kit Kat-20
# Double Bubble-34
# Milky Way-74
# Three Musketeers-32
#
# ```

# %%
candy_list = ['Jelly Belly','Kit Kat','Double Bubble','Milky Way','Three Musketeers']
no_of_items = [10,20,34,74,32]

l= zip(candy_list,no_of_items)
for i in l:
 print('-'.join(map(str,i)))
# Out:
# Jelly Belly-10
# Kit Kat-20
# Double Bubble-34
# Milky Way-74
# Three Musketeers-32

# %% [markdown]
# ###`Problem 4:` Running Sum on list
# Write a program to print a list after performing running sum on it.
#
# i.e:
#
# `Input:`
# ```
# list1 = [1,2,3,4,5,6]
# ```
# `Output:`
# ```
# [1,3,6,10,15,21]
# ```

# %%
# l=[]
# list1 = [1,2,3,4,5,6]
# total=0

# for i in list1:
#   total+= i
#   l.append(total)

# print(l)



# LIST COMPREHENSION
list1=[1,2,3,4,5,6]
[sum(list1[:i+1]) for i in range(len(list1)) ]  #sum cannot take a single value as iterable
# Out:
# [1, 3, 6, 10, 15, 21]

# %% [markdown]
# ###`Problem 5:` You are given a list of integers. You are asked to make a list by running through elements of the list by adding all elements greater and itself.
#
# i.e. Say given list is `[2,4,6,10,1]`
# resultant list will be `[22,20,10,23]`.
#
# For 1st element `2` ->> these are greater `(4+6+10)` values and `2` itself so on adding becomes `22`.
#
# For 2nd element `4` ->> greater elements are `(6, 10)` and `4` itself, so on adding `20`
#
# like wise for all other elememts.
#
# `[2,4,6,10,1]`-->`[22,20,16,10,23]`

# %%
# list1= [2,4,6,10,1]
# l=[]

# for i in list1:
#   total=i
#   for j in list1:
#    if i <j:
#     total +=j
#   l.append(total)

# print(l)



#list comprehension
list1 = [2, 4, 6, 10, 1]
l = [sum(j for j in list1 if i<j ) + i for i in list1]
print(l)
# Out:
# [22, 20, 16, 10, 23]

# %% [markdown]
# ###`Problem 6:` Find list of common unique items from two list. and show in increasing order
#
# `Input`
#
# ```
# num1 = [23,45,67,78,89,34]
# num2 = [34,89,55,56,39,67]
# ```
#
# `Output:`
# ```
# [34, 67, 89]
# ```

# %%
# num1 = [23,45,67,78,89,34]
# num2 = [34,89,55,56,39,67]
# l=[]

# for i in num1:
#   for j in num2:
#     if i==j:
#       l.append(i)

# l=sorted(l)
# print(l)

#LIST COMPREHENSION
num1 = [23,45,67,78,89,34]
num2 = [34,89,55,56,39,67]

l=[i for i in num1 for j in num2 if i==j ]
l=sorted(l)
print(l)
# Out:
# [34, 67, 89]

# %% [markdown]
# ###`Problem 7:` Sort a list of alphanumeric strings based on product value of numeric character in it. If in any string there is no numeric character take it's product value as 1.
#
# `Input:`
# ```
# ['1ac21', '23fg', '456', '098d','1','kls']
# ```
#
# `Output:`
# ```
# ['456', '23fg', '1ac21', '1', 'kls', '098d']
#
# ```

# %%
l=['1ac21', '23fg', '456', '098d','1','kls']

l1=[]
for i in l:
 product=1
 for j in i:
    if j.isdigit():
      product*=int(j)
 l1.append([product,i])

# n=len(l1)
# for i in range(n):
#   for  j in range(0,n-i-1):
#     if l1[j][0]<l1[j+1][0]:
#       l1[j],l1[j+1]=l1[j+1],l1[j]

# result=[]
# for i in l1:
#   result.append(i[1])
# print(result)

l1.sort(key=lambda x: x[0], reverse=True)
[i[1] for i in l1]
# Out:
# ['456', '23fg', '1ac21', '1', 'kls', '098d']

# %% [markdown]
# `Problem 8:` Split String of list on K character.
#
# **Example :**
#
# Input:
# ```bash
# ['CampusX is a channel', 'for data-science', 'aspirants.']
# ```
#
# Output:
# ```bash
# ['CampusX', 'is', 'a', 'channel', 'for', 'data-science', 'aspirants.']
# ```

# %%
l=['CampusX is a channel', 'for data-science', 'aspirants.']
m=' '.join(l)
l1=[]
l1= m.split()
print(l1)
# Out:
# ['CampusX', 'is', 'a', 'channel', 'for', 'data-science', 'aspirants.']

# %% [markdown]
# ### `Problem 9:` Convert Character Matrix to single String using string comprehension.
#
# **Example 1:**
#
# Input:
# ```bash
# [['c', 'a', 'm', 'p', 'u', 'x'], ['i', 's'], ['b', 'e', 's', 't'], ['c', 'h', 'a', 'n', 'n', 'e', 'l']]
# ```
#
# Output:
# ```bash
# campux is best channel
# ```

# %%
l=[['c', 'a', 'm', 'p', 'u', 'x'], ['i', 's'], ['b', 'e', 's', 't'], ['c', 'h', 'a', 'n', 'n', 'e', 'l']]
# m=[]
# for i in l:
#   m.append(''.join(i))
# print(m)
# print(' '.join(m))

print(' '.join([''.join(i) for i in l]))
# Out:
# campux is best channel

# %% [markdown]
# ### `Problem 10:` Add Space between Potential Words.
#
# **Example:**
#
# Input:
#
# ```bash
# ['campusxIs', 'bestFor', 'dataScientist']
# ```
#
# Output:
# ```bash
# ['campusx Is', 'best For', 'data Scientist']
# ```

# %%
m=['campusxIs', 'bestFor', 'dataScientist']

[''.join(c if c.islower() else ' '+ c for c in word) for word in m]
# Out:
# ['campusx Is', 'best For', 'data Scientist']

# %% [markdown]
# ### `Problem 11:` Write a program that can perform union operation on 2 lists
#
# **Example:**
#
# Input:
#
# ```bash
# [1,2,3,4,5,1]
# [2,3,5,7,8]
# ```
#
# Output:
# ```bash
# [1,2,3,4,5,7,8]
# ```

# %%
l=[1,2,3,4,5,1]
l2=[2,3,5,7,8]

result= list(set(l).union(set(l2)))
print(result)




# l1=[]
# for i in l:
#   flag=0
#   for j in l1:
#     if i ==j:
#       flag +=1
#   if flag !=1:
#     l1.append(i)

# for i in l2:
#   flag=True
#   for j in l1:
#     if i == j:
#       flag= False

#   if flag== True:
#     l1.append(i)


# l1.sort()
# print(l1)
# Out:
# [1, 2, 3, 4, 5, 7, 8]

# %% [markdown]
# ### `Problem 12:` Write a program that can find the max number of each row of a matrix
#
# **Example:**
#
# Input:
#
# ```bash
# [[1,2,3],[4,5,6],[7,8,9]]
# ```
#
# Output:
# ```bash
# [3,6,9]
# ```

# %%
l=[[1,2,3],[4,5,6],[7,8,9]]

[max(num) for num in l ]
# Out:
# [3, 6, 9]

# %% [markdown]
# ### `Problem 13:` Write a list comprehension to print the following matrix
#
# [[0, 1, 2], [3, 4, 5], [6, 7, 8]]

# %%
[[j + i*3 for j in range(3)] for i in range(3)]
# Out:
# [[0, 1, 2], [3, 4, 5], [6, 7, 8]]

# %% [markdown]
# ### `Problem 14:` Write a list comprehension that can transpose a given matrix
#
# matrix = [<br>
#   [1,2,3],<br>
#           [4,5,6],<br>
#           [7,8,9]<br>]<br>
#
# [1, 4, 7]<br>
# [2, 5, 8]<br>
# [3, 6, 9]<br>

# %%
matrix = [
[1,2,3],
[4,5,6],
[7,8,9]
]

# [[matrix[j][i] for j in range(len(matrix))] for i in range(len(matrix[0]))]
[list(row) for row in zip(*matrix)]
# Out:
# [[1, 4, 7], [2, 5, 8], [3, 6, 9]]

# %% [markdown]
# ### `Problem 15:` Write a list comprehension that can flatten a nested list
#
# Input<br>
# matrix = [<br>
#   [1,2,3],<br>
#           [4,5,6],<br>
#           [7,8,9]<br>]<br>
#
# Output:<br>
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
matrix = [
[1,2,3],
[4,5,6],
[7,8,9]
]

[i for word in matrix for i in word]

# m=[]
# for i in matrix:
#  m.extend(i)
# print(m)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
