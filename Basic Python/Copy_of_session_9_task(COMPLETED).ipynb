# %% [markdown]
# ### `Problem-1:` Class inheritence
#
# Create a **Bus** child class that inherits from the Vehicle class. The default fare charge of any vehicle is seating capacity * 100. If Vehicle is Bus instance, we need to add an extra 10% on full fare as a maintenance charge. So total fare for bus instance will become the final amount = total fare + 10% of the total fare.
#
# Note: The bus seating capacity is 50. so the final fare amount should be 5500. You need to override the fare() method of a Vehicle class in Bus class.

# %%
class Vehicle:
    def __init__(self):
        self.__fare=100
    
    def get_fare(self):
        return self.__fare
    
    def fare(self,num):
        total_fare= num*self.__fare
        return total_fare
     

class Bus(Vehicle):
    def fare(self,num):
        if num<= 50:
            fare=super().fare(num)
            total_fare= fare + 0.1*fare
            return total_fare
        else:
            return 'Bus is full'

# %%
b= Bus()
result=b.fare(23)
print(result)
# Out:
# 2530.0

# %% [markdown]
# ### `Problem-3:` Write a program that has a class Point. Define another class Location which has two objects (Location & Destination) of class Point. Also define a function in Location that prints the reflection of Destination on the x axis.

# %%
#aggregation relation
class Point:
    def __init__(self,x,y):
        self.x=x
        self.y=y
    
    def __str__(self):
        return f'{self.x},{self.y}'

class Location:
    def __init__(self,l1,d1):
        self.location=l1
        self.destination= d1
    
    def reflection(self):
        return Point(self.destination.x,-self.destination.y)

p1=Point(2,3)
p2= Point(4,5)
l=Location(p1,p2)
print(l.reflection())
# Out:
# 4,-5

# %% [markdown]
# ### `Problem-4:` Write a program that has an abstract class Polygon. Derive two classes Rectangle and Triamgle from Polygon and write methods to get the details of their dimensions and hence calculate the area.

# %%
from abc import ABC,abstractmethod
class Polygon(ABC):
    @abstractmethod
    def get_dimension(self):
        pass
    
    @abstractmethod 
    def get_area(self):
        pass

class Rectangle(Polygon):
    def __init__(self):
        self.length=None
        self.breadth=None

    def get_dimension(self,l,b):
        self.length=l
        self.breadth=b
    
    def get_area(self):
        return f'The area of given rectangle is {self.breadth*self.length}'
    

class Triangle(Polygon):

    def __init__(self):
        self.base=None
        self.height=None

    def get_dimension(self,l,h):
        self.base=l
        self.height=h
    
    def get_area(self):
        return f'The area of given triangle is {0.5*self.height*self.base}'

# %%
r = Rectangle()
r.get_dimension(10, 5)
print(r.get_area())

t = Triangle()
t.get_dimension(10, 4)
print(t.get_area())
# Out:
# The area of given rectangle is 50
# The area of given triangle is 20.0

# %% [markdown]
# ### `Problem-5:` Write a program with class Bill. The users have the option to pay the bill either by cheque or by cash. Use the inheritance to model this situation.

# %%
class Bill:
    def __init__(self):
        self.BIll_no=None
        self.name=None
        self.amount=None
        
    
    def menu(self):
        self.BIll_no,self.name,self.amount = input('Enter the bill no:'),input('Enter your name:'),input('Enter the amount to pay:')

class Cash(Bill):

    def __init__(self):
        super().__init__()
        self.menu()

    def pay(self):
        print('Paid by cash')
        print(f'Bill no = {self.BIll_no}')
        print(f'Name    = {self.name}')
        print(f'Amount  = {self.amount}')

class Cheque(Bill):
    def __init__(self):
        super().__init__()
        self.cheque_no= None
        self.Bank_name=None
        self.Date= None
        self.menu()
        

    def pay(self):
        print('Paid by chque')
        print(f'Bill no   = {self.BIll_no}')
        print(f'Name      = {self.name}')
        print(f'Amount    = {self.amount}')    
        print(f'Cheque no = {self.cheque_no}')    
        print(f'Bank name = {self.Bank_name}')    
        print(f'Date      = {self.Date}')

    def menu(self):
        super().menu()
        self.cheque_no,self.Bank_name,self.Date = input('Enter the cheque no:'),input('Enter the Bank name:'),input('Enter the date of cheque:')

# %%
c=Cheque()
c.pay()
# Out:
# Paid by chque
# Bill no   = 1
# Name      = s
# Amount    = 1
# Cheque no = 1
# Bank name = s
# Date      = 1

# %% [markdown]
# ###`Q-6:` FlexibleDict
# As of now we are accessing values from dictionary with exact keys. Now we want to amend accessing values functionality. if a dict have key `1` (int) the even if we try to access values by giving `'1'` (1 as str) as key, we should get the same result and vice versa.
#
# Write a class `FlexibleDict` upon builtin `dict` class with above required functionality.
#
# Hint- `dict[key] => dict.__getitem__(key)`

# %% [markdown]
# Ex.
# ```
# fd = FlexibleDict()
# fd['a'] = 100
# print(fd['a']) # Like regular dict
#
# fd[5] = 500
# print(fd[5]) # Like regular dict
#
# fd[1] = 100
# print(fd['1']) # actual Key is int but still trying to access through str key.
# fd['1'] = 100
# print(fd[1])
#
# ```
# `Output:`
# ```
# 100
# 500
# 100
# 100
#
# ```

# %%
class FlexibleDict(dict):
    
    def __getitem__(self, key):
        try:
            int_key = int(key)
            return super().__getitem__(int_key)

        except (ValueError,TypeError):
            pass
        
        return super().__getitem__(key)

# %%
fd = FlexibleDict()
fd['a'] = 100
print(fd['a'])
# Out:
# 100
